# %% [markdown]
# How many multiplications and additions do you need to multiply a matrix between a (n, k) and (k, m) matrix? Explain.
#
# Ans. Since the resulting matrix will have (n, m) configuration, thus n*m elements, meaning n*m computations. As for multiplications, the first and
#     second matrices have k elements in each row and column. Therefore, n*m*k will be the total no. of multiplications. Similarly, after the k
#     multiplications, we'll be adding them; therefore, for k multiplications, we'll need (k-1) additions. Therefore, there is a total of n*m*(k-1) no.
#     of additions.

# %% [markdown]
# Write Python code to multiply the above two matrices. Solve using list of lists and then use numpy. Compare the timing of both solutions. Which one is
# faster? Why?

# %%
# Using lists

def matrix_multiply_lists(matrix_a, matrix_b):
    result = [[0 for ele in range(len(matrix_b[0]))] for ele in range(len(matrix_a))]
    
    for i in range(len(matrix_a)):  
        for j in range(len(matrix_b[0])):
            for k in range(len(matrix_b)):
                result[i][j] += matrix_a[i][k] * matrix_b[k][j]
                
    return result

# %%
# Using NumPy

import numpy as np

def matrix_multiply_numpy(matrix_a, matrix_b):
    return np.dot(matrix_a, matrix_b)

# %% [markdown]
# NumPy is significantly faster compared to using the lists method. NumPy is highly optimized and uses efficient algorithms, resulting in faster execution.

# %% [markdown]
# What is the gradient of the following function with respect to x and y? (x^2)*y + (y^3)*sin x
#
# Ans. With respect to x: 2xy + (y^3)* cos x
#      With respect to y: x^2 + 3y^2 sin x

# %% [markdown]
# Using matplotlib plot the following functions on the domain: x = 0.5 to 100.0 in steps of 0.5.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the domain
x_values = np.arange(0.5, 100, 0.5)

# Define the functions
y1 = x_values
y2 = x_values**2
y3 = (x_values**3) / 100
y4 = np.sin(x_values)
y5 = np.sin(x_values) / x_values
y6 = np.log(x_values)
y7 = np.exp(x_values)

# Plot the functions
plt.figure(figsize=(15, 10))

plt.subplot(3, 3, 1)
plt.plot(x_values, y1)
plt.title('y = x')

plt.subplot(3, 3, 2)
plt.plot(x_values, y2)
plt.title('y = x^2')

plt.subplot(3, 3, 3)
plt.plot(x_values, y3)
plt.title('y = (x^3)/100')

plt.subplot(3, 3, 4)
plt.plot(x_values, y4)
plt.title('y = sin(x)')

plt.subplot(3, 3, 5)
plt.plot(x_values, y5)
plt.title('y = sin(x)/x')

plt.subplot(3, 3, 6)
plt.plot(x_values, y6)
plt.title('y = log(x)')

plt.subplot(3, 3, 7)
plt.plot(x_values, y7)
plt.title('y = e^x')

plt.show()

# %% [markdown]
# Finding the highest element in a list requires one pass of the array. Finding the second highest element requires 2 passes of the the array. Using this method, what is the time complexity of finding the median of the array? Can you suggest a better method? Can you implement both these methods in Python and compare against numpy.median routine in terms of time?
#
# Ans. The time complexity of finding the median is O(n^2), where n is the array's length. A better way with the time complexity of O(n log n) is sorting and finding the median.

# %%
import numpy as np
import timeit

def one_pass_method(arr):
    n = len(arr)
    for i in range(n // 2):
        max_val = max(arr)
        arr.remove(max_val)
    return arr[0] if n % 2 != 0 else (arr[0] + max(arr)) / 2

def median_sorting(arr):
    # Finding the median using sorting
    sorted_arr = sorted(arr)
    n = len(sorted_arr)
    return sorted_arr[n // 2] if n % 2 != 0 else (sorted_arr[n // 2 - 1] + sorted_arr[n // 2]) / 2

# Generate a random array for testing
arr = np.random.rand(100)

# Measure the time for the one-pass method
one_pass_time = timeit.timeit(lambda: one_pass_method(arr.copy().tolist()), number=10)

# Measure the time for the sorting method
sorting_time = timeit.timeit(lambda: median_sorting(arr.copy()), number=10)

# Measure the time for numpy.median
numpy_time = timeit.timeit(lambda: np.median(arr), number=10)

# Print the results
print("One-pass method time:", one_pass_time)
print("Sorting method time:", sorting_time)
print("Numpy median time:", numpy_time)
# Out:
# One-pass method time: 0.0049000000008163624
# Sorting method time: 0.001299999999901047
# Numpy median time: 0.002599999999802094
